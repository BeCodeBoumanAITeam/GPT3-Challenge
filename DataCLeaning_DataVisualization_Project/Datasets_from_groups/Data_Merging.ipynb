# %%
import numpy as np
import pandas as pd

# %%
AMN_E=pd.read_csv('amn_e.csv')
AMN_R=pd.read_csv('amn_r.csv')
odc=pd.read_csv('odc.csv')
fpo=pd.read_csv('fpo.csv')
saa_h=pd.read_csv('saa_h.csv')
saa_i=pd.read_csv('saa_i.csv')
mds=pd.read_csv('mds.csv')
ejs=pd.read_csv('ejs.csv')

# %%
print(AMN_E.head(5))
# Out:
#    Unnamed: 0             Locality Type of Property                  Sub Type  \
# 0         0.0   Antwerpen-Centrum              Huis          Historische pand
# 1         1.0         Lasne/Ohain            Maison  Établissement historique
# 2         2.0      Antwerpen-Noord             Huis                     Villa
# 3         3.0      Antwerpen-Noord             Huis          Historische pand
# 4         4.0   Sint-Martens-Latem             Huis          Historische pand
#
#           Price Type of Sale No of Rooms Area(sqft) Equipped(Y/N)  \
# 0   12,500,000          Huis           8  20.343,79           NaN
# 1    6,500,000        Maison          16         18           NaN
# 2    5,850,000          Huis          10  12.163,22           NaN
# 3    4,950,000          Huis          30  26.909,78           NaN
# 4    4,800,000          Huis        None      11,12           NaN
#
#   Furnished(Y/N) Open Fire(Y/N) Terrace Area Garden Area  \
# ...

# %%
print(AMN_R.head(5))
# Out:
#                                                                                              Locality  \
# Rue Rimière 105, 4120 Rotheux-Rimière, Neupré                                                       0
# Sint-Truidensesteenweg 95A A, 3350 Orsmaal-Guss...  \n\n\n\n340000\n\n\t\t\t\t\t\t\t\t\t€ 340.000\...
# Augustijnenlaan 77 201, 2200 Herentals              \n\n\n\n259000\n\n\t\t\t\t\t\t\t\t\t€ 259.000\...
# Averbodesesteenweg 19, 2230 Herselt                 \n\n\n\n449000\n\n\t\t\t\t\t\t\t\t\t€ 449.000\...
# Edward pynaertkaai 21, 9050 Ledeberg                \n\n\n\n249900\n\n\t\t\t\t\t\t\t\t\t€ 249.900\...
#
#                                                     Price Property type  \
# Rue Rimière 105, 4120 Rotheux-Rimière, Neupré       House             0
# Sint-Truidensesteenweg 95A A, 3350 Orsmaal-Guss...  House             3
# Augustijnenlaan 77 201, 2200 Herentals               Flat             2
# ...

# %%
with open('amn_e.csv', 'r') as txtReader:
    with open('amn_e_new.csv', 'w') as txtWriter:
        for line in txtReader.readlines():
            line = line.replace('\\n', '')
            txtWriter.write(line)

# %%
AMN_R_NEW=pd.read_csv('amn_r_new.csv')
AMN_R_NEW
# Out:
#                                                                                              Locality  \
# Rue Rimière 105, 4120 Rotheux-Rimière, Neupré                                                       0
# Sint-Truidensesteenweg 95A A, 3350 Orsmaal-Guss...  \n\n\n\n340000\n\n\t\t\t\t\t\t\t\t\t€ 340.000\...
# Augustijnenlaan 77 201, 2200 Herentals              \n\n\n\n259000\n\n\t\t\t\t\t\t\t\t\t€ 259.000\...
# Averbodesesteenweg 19, 2230 Herselt                 \n\n\n\n449000\n\n\t\t\t\t\t\t\t\t\t€ 449.000\...
# Edward pynaertkaai 21, 9050 Ledeberg                \n\n\n\n249900\n\n\t\t\t\t\t\t\t\t\t€ 249.900\...
# ...                                                                                               ...
# Avenue andre drouart 26, 1160 Auderghem             \n\n\n\n525000\n\n\t\t\t\t\t\t\t\t\t€ 525.000\...
# 1400 Nivelles                                       \n\n\n\n275000\n\n\t\t\t\t\t\t\t\t\t€ 275.000\...
# ...

# %%
AMN_E_NEW=pd.read_csv('amn_e_new.csv')

# %%
AMN_E_NEW
# Out:
#       Unnamed: 0                        Locality Type of Property  \
# 0            0.0              Antwerpen-Centrum              Huis
# 1            1.0                    Lasne/Ohain            Maison
# 2            2.0                 Antwerpen-Noord             Huis
# 3            3.0                 Antwerpen-Noord             Huis
# 4            4.0              Sint-Martens-Latem             Huis
# ...          ...                             ...              ...
# 4613      3980.0                    Sant Gervasi        Apartment
# 4614      3981.0   Saarbrücken (Regionalverband)          Wohnung
# 4615      3982.0                            Roma        Apartment
# 4616      3983.0                        Eixample        Apartment
# 4617      3984.0            Marbella Golden Mile        Apartment
#
#                       Sub Type         Price Type of Sale No of Rooms  \
# 0             Historische pand   12,500,000          Huis           8
# ...

# %%
AMN_E_NEW.drop(AMN_E_NEW.columns[AMN_E_NEW.columns.str.contains('unnamed',case=False)],axis=1, inplace=True)

# %%
AMN_E_NEW
# Out:
#                             Locality Type of Property  \
# 0                 Antwerpen-Centrum              Huis
# 1                       Lasne/Ohain            Maison
# 2                    Antwerpen-Noord             Huis
# 3                    Antwerpen-Noord             Huis
# 4                 Sint-Martens-Latem             Huis
# ...                              ...              ...
# 4613                    Sant Gervasi        Apartment
# 4614   Saarbrücken (Regionalverband)          Wohnung
# 4615                            Roma        Apartment
# 4616                        Eixample        Apartment
# 4617            Marbella Golden Mile        Apartment
#
#                       Sub Type         Price Type of Sale No of Rooms  \
# 0             Historische pand   12,500,000          Huis           8
# 1     Établissement historique    6,500,000        Maison          16
# 2                        Villa    5,850,000          Huis          10
# ...

# %%
AMN_E_NEW.columns
# Out:
# Index(['Locality', 'Type of Property', 'Sub Type', 'Price', 'Type of Sale',
#        'No of Rooms', 'Area(sqft)', 'Equipped(Y/N)', 'Furnished(Y/N)',
#        'Open Fire(Y/N)', 'Terrace Area', 'Garden Area',
#        'Surface of the Land(sqft)', 'Surface area of the Plot(sqft)',
#        'No of Facades', 'Simming Pool(Y/N)', 'State of the Building'],
#       dtype='object')

# %%
#AMN_E_NEW.insert(loc=len(AMN_E_NEW.columns), column='Terrace (Y/N)',value="")
AMN_E_NEW.insert(loc=len(AMN_E_NEW.columns), column='Garden (Y/N)',value="")
AMN_E_NEW.insert(loc=len(AMN_E_NEW.columns), column='Link (Y/N)',value="")

# %%
AMN_E_NEW
# Out:
#                             Locality Type of Property  \
# 0                 Antwerpen-Centrum              Huis
# 1                       Lasne/Ohain            Maison
# 2                    Antwerpen-Noord             Huis
# 3                    Antwerpen-Noord             Huis
# 4                 Sint-Martens-Latem             Huis
# ...                              ...              ...
# 4613                    Sant Gervasi        Apartment
# 4614   Saarbrücken (Regionalverband)          Wohnung
# 4615                            Roma        Apartment
# 4616                        Eixample        Apartment
# 4617            Marbella Golden Mile        Apartment
#
#                       Sub Type         Price Type of Sale No of Rooms  \
# 0             Historische pand   12,500,000          Huis           8
# 1     Établissement historique    6,500,000        Maison          16
# 2                        Villa    5,850,000          Huis          10
# ...

# %%
result=pd.concat([AMN_E,AMN_R,odc,fpo,saa_h,saa_i,mds,ejs], axis=0, ignore_index=True)

# %%
result
# Out:
#        Unnamed: 0             Locality Type of Property  \
# 0             0.0   Antwerpen-Centrum              Huis
# 1             1.0         Lasne/Ohain            Maison
# 2             2.0      Antwerpen-Noord             Huis
# 3             3.0      Antwerpen-Noord             Huis
# 4             4.0   Sint-Martens-Latem             Huis
# ...           ...                  ...              ...
# 79872     11518.0                 1000              NaN
# 79873     11519.0                 9700              NaN
# 79874     11520.0                 3000              NaN
# 79875     11521.0                 9950              NaN
# 79876     11522.0                 1090              NaN
#
#                        Sub Type         Price Type of Sale No of Rooms  \
# 0              Historische pand   12,500,000          Huis           8
# 1      Établissement historique    6,500,000        Maison          16
# 2                         Villa    5,850,000          Huis          10
# ...

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'Locality', 'Type of Property', 'Sub Type', 'Price',
#        'Type of Sale', 'No of Rooms', 'Area(sqft)', 'Equipped(Y/N)',
#        'Furnished(Y/N)',
#        ...
#        'Price type', 'Price additional value', 'Url', 'Type of property',
#        'Living surface area', 'Kitchen', 'Open fire', 'Surface of the land',
#        'Number of facades', 'State of the building'],
#       dtype='object', length=122)
